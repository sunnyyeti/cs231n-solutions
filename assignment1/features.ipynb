# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# /home/hao/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
  # Load the raw CIFAR-10 data
  cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # Subsample the data
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]

  return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for the bonus section.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 15 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-8,5e-8,1e-7,5e-7,1e-6,5e-6]
regularization_strengths = [4000,6000,8000,10000,30000,40000,58000,60000]

results = {}
best_val = -1
best_svm = None

pass
################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
bins = [10,13,15,17]
for num_color_bins in bins:
    #num_color_bins = 15 # Number of bins in the color histogram
    feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
    X_train_feats = extract_features(X_train, feature_fns, verbose=True)
    X_val_feats = extract_features(X_val, feature_fns)
    X_test_feats = extract_features(X_test, feature_fns)
    
    # Preprocessing: Subtract the mean feature
    mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
    X_train_feats -= mean_feat
    X_val_feats -= mean_feat
    X_test_feats -= mean_feat
    
    # Preprocessing: Divide by standard deviation. This ensures that each feature
    # has roughly the same scale.
    std_feat = np.std(X_train_feats, axis=0, keepdims=True)
    X_train_feats /= std_feat
    X_val_feats /= std_feat
    X_test_feats /= std_feat
    
    # Preprocessing: Add a bias dimension
    X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
    X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
    X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
    for alpha in learning_rates:
        for reg in regularization_strengths:
            #print(alpha,reg)
            svm = LinearSVM()
            svm.train(X_train_feats, y_train, learning_rate=alpha, reg=reg,
                          num_iters=2000, verbose=False)
            y_train_pred = svm.predict(X_train_feats)
            train_accuracy = np.mean(y_train == y_train_pred)
            y_val_pred = svm.predict(X_val_feats)
            val_accuracy = np.mean(y_val == y_val_pred)
            results[(num_color_bins,alpha,reg)] = (train_accuracy,val_accuracy)
            if val_accuracy > best_val:
                best_val = val_accuracy
                best_svm = svm
                best_bins = num_color_bins
                best_lr = alpha
                best_reg = reg
pass
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for bins, lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(bins, lr, reg)]
    print 'bins %d  lr %e reg %e train accuracy: %f val accuracy: %f' % (
                bins, lr, reg,  train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f, bins:%f, lr:%f,reg:%f' % (best_val,best_bins,best_lr,best_reg)
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# bins 10  lr 1.000000e-08 reg 4.000000e+03 train accuracy: 0.109633 val accuracy: 0.103000
# bins 10  lr 1.000000e-08 reg 6.000000e+03 train accuracy: 0.120102 val accuracy: 0.146000
# bins 10  lr 1.000000e-08 reg 8.000000e+03 train accuracy: 0.096837 val accuracy: 0.090000
# bins 10  lr 1.000000e-08 reg 1.000000e+04 train accuracy: 0.104122 val accuracy: 0.105000
# bins 10  lr 1.000000e-08 reg 3.000000e+04 train accuracy: 0.119408 val accuracy: 0.121000
# bins 10  lr 1.000000e-08 reg 4.000000e+04 train accuracy: 0.105184 val accuracy: 0.087000
# bins 10  lr 1.000000e-08 reg 5.800000e+04 train accuracy: 0.131592 val accuracy: 0.151000
# bins 10  lr 1.000000e-08 reg 6.000000e+04 train accuracy: 0.086224 val accuracy: 0.086000
# bins 10  lr 5.000000e-08 reg 4.000000e+03 train accuracy: 0.125429 val accuracy: 0.128000
# bins 10  lr 5.000000e-08 reg 6.000000e+03 train accuracy: 0.123429 val accuracy: 0.115000
# bins 10  lr 5.000000e-08 reg 8.000000e+03 train accuracy: 0.118143 val accuracy: 0.127000
# bins 10  lr 5.000000e-08 reg 1.000000e+04 train accuracy: 0.142245 val accuracy: 0.143000
# bins 10  lr 5.000000e-08 reg 3.000000e+04 train accuracy: 0.169102 val accuracy: 0.186000
# bins 10  lr 5.000000e-08 reg 4.000000e+04 train accuracy: 0.213408 val accuracy: 0.219000
# bins 10  lr 5.000000e-08 reg 5.800000e+04 train accuracy: 0.373776 val accuracy: 0.372000
# bins 10  lr 5.000000e-08 reg 6.000000e+04 train accuracy: 0.387327 val accuracy: 0.396000
# bins 10  lr 1.000000e-07 reg 4.000000e+03 train accuracy: 0.135918 val accuracy: 0.121000
# bins 10  lr 1.000000e-07 reg 6.000000e+03 train accuracy: 0.124714 val accuracy: 0.133000
# bins 10  lr 1.000000e-07 reg 8.000000e+03 train accuracy: 0.161469 val accuracy: 0.175000
# bins 10  lr 1.000000e-07 reg 1.000000e+04 train accuracy: 0.172939 val accuracy: 0.178000
# bins 10  lr 1.000000e-07 reg 3.000000e+04 train accuracy: 0.405245 val accuracy: 0.398000
# bins 10  lr 1.000000e-07 reg 4.000000e+04 train accuracy: 0.417224 val accuracy: 0.420000
# bins 10  lr 1.000000e-07 reg 5.800000e+04 train accuracy: 0.416000 val accuracy: 0.420000
# bins 10  lr 1.000000e-07 reg 6.000000e+04 train accuracy: 0.413592 val accuracy: 0.411000
# bins 10  lr 5.000000e-07 reg 4.000000e+03 train accuracy: 0.414367 val accuracy: 0.417000
# bins 10  lr 5.000000e-07 reg 6.000000e+03 train accuracy: 0.413286 val accuracy: 0.412000
# bins 10  lr 5.000000e-07 reg 8.000000e+03 train accuracy: 0.414878 val accuracy: 0.420000
# bins 10  lr 5.000000e-07 reg 1.000000e+04 train accuracy: 0.413694 val accuracy: 0.417000
# bins 10  lr 5.000000e-07 reg 3.000000e+04 train accuracy: 0.414510 val accuracy: 0.418000
# bins 10  lr 5.000000e-07 reg 4.000000e+04 train accuracy: 0.410796 val accuracy: 0.396000
# bins 10  lr 5.000000e-07 reg 5.800000e+04 train accuracy: 0.413898 val accuracy: 0.416000
# bins 10  lr 5.000000e-07 reg 6.000000e+04 train accuracy: 0.412306 val accuracy: 0.414000
# bins 10  lr 1.000000e-06 reg 4.000000e+03 train accuracy: 0.417571 val accuracy: 0.410000
# bins 10  lr 1.000000e-06 reg 6.000000e+03 train accuracy: 0.413327 val accuracy: 0.421000
# bins 10  lr 1.000000e-06 reg 8.000000e+03 train accuracy: 0.415367 val accuracy: 0.418000
# bins 10  lr 1.000000e-06 reg 1.000000e+04 train accuracy: 0.416755 val accuracy: 0.423000
# bins 10  lr 1.000000e-06 reg 3.000000e+04 train accuracy: 0.416490 val accuracy: 0.422000
# bins 10  lr 1.000000e-06 reg 4.000000e+04 train accuracy: 0.409000 val accuracy: 0.405000
# bins 10  lr 1.000000e-06 reg 5.800000e+04 train accuracy: 0.408857 val accuracy: 0.397000
# bins 10  lr 1.000000e-06 reg 6.000000e+04 train accuracy: 0.407184 val accuracy: 0.425000
# bins 10  lr 5.000000e-06 reg 4.000000e+03 train accuracy: 0.415224 val accuracy: 0.421000
# bins 10  lr 5.000000e-06 reg 6.000000e+03 train accuracy: 0.411837 val accuracy: 0.410000
# bins 10  lr 5.000000e-06 reg 8.000000e+03 train accuracy: 0.408551 val accuracy: 0.395000
# bins 10  lr 5.000000e-06 reg 1.000000e+04 train accuracy: 0.402122 val accuracy: 0.400000
# bins 10  lr 5.000000e-06 reg 3.000000e+04 train accuracy: 0.409449 val accuracy: 0.401000
# bins 10  lr 5.000000e-06 reg 4.000000e+04 train accuracy: 0.395408 val accuracy: 0.398000
# bins 10  lr 5.000000e-06 reg 5.800000e+04 train accuracy: 0.381143 val accuracy: 0.374000
# bins 10  lr 5.000000e-06 reg 6.000000e+04 train accuracy: 0.380327 val accuracy: 0.383000
# bins 13  lr 1.000000e-08 reg 4.000000e+03 train accuracy: 0.109286 val accuracy: 0.109000
# bins 13  lr 1.000000e-08 reg 6.000000e+03 train accuracy: 0.113245 val accuracy: 0.118000
# bins 13  lr 1.000000e-08 reg 8.000000e+03 train accuracy: 0.101694 val accuracy: 0.080000
# bins 13  lr 1.000000e-08 reg 1.000000e+04 train accuracy: 0.097204 val accuracy: 0.094000
# bins 13  lr 1.000000e-08 reg 3.000000e+04 train accuracy: 0.089327 val accuracy: 0.088000
# bins 13  lr 1.000000e-08 reg 4.000000e+04 train accuracy: 0.102837 val accuracy: 0.105000
# bins 13  lr 1.000000e-08 reg 5.800000e+04 train accuracy: 0.105694 val accuracy: 0.105000
# bins 13  lr 1.000000e-08 reg 6.000000e+04 train accuracy: 0.093204 val accuracy: 0.088000
# bins 13  lr 5.000000e-08 reg 4.000000e+03 train accuracy: 0.095980 val accuracy: 0.104000
# bins 13  lr 5.000000e-08 reg 6.000000e+03 train accuracy: 0.099857 val accuracy: 0.107000
# bins 13  lr 5.000000e-08 reg 8.000000e+03 train accuracy: 0.102224 val accuracy: 0.101000
# bins 13  lr 5.000000e-08 reg 1.000000e+04 train accuracy: 0.109980 val accuracy: 0.121000
# bins 13  lr 5.000000e-08 reg 3.000000e+04 train accuracy: 0.176204 val accuracy: 0.173000
# bins 13  lr 5.000000e-08 reg 4.000000e+04 train accuracy: 0.244857 val accuracy: 0.253000
# bins 13  lr 5.000000e-08 reg 5.800000e+04 train accuracy: 0.374102 val accuracy: 0.369000
# bins 13  lr 5.000000e-08 reg 6.000000e+04 train accuracy: 0.390980 val accuracy: 0.404000
# bins 13  lr 1.000000e-07 reg 4.000000e+03 train accuracy: 0.146633 val accuracy: 0.133000
# bins 13  lr 1.000000e-07 reg 6.000000e+03 train accuracy: 0.133714 val accuracy: 0.130000
# bins 13  lr 1.000000e-07 reg 8.000000e+03 train accuracy: 0.142857 val accuracy: 0.151000
# bins 13  lr 1.000000e-07 reg 1.000000e+04 train accuracy: 0.166429 val accuracy: 0.171000
# bins 13  lr 1.000000e-07 reg 3.000000e+04 train accuracy: 0.416327 val accuracy: 0.421000
# bins 13  lr 1.000000e-07 reg 4.000000e+04 train accuracy: 0.418082 val accuracy: 0.424000
# bins 13  lr 1.000000e-07 reg 5.800000e+04 train accuracy: 0.416694 val accuracy: 0.425000
# bins 13  lr 1.000000e-07 reg 6.000000e+04 train accuracy: 0.415082 val accuracy: 0.421000
# bins 13  lr 5.000000e-07 reg 4.000000e+03 train accuracy: 0.408837 val accuracy: 0.399000
# bins 13  lr 5.000000e-07 reg 6.000000e+03 train accuracy: 0.416796 val accuracy: 0.430000
# bins 13  lr 5.000000e-07 reg 8.000000e+03 train accuracy: 0.417061 val accuracy: 0.419000
# bins 13  lr 5.000000e-07 reg 1.000000e+04 train accuracy: 0.418878 val accuracy: 0.432000
# bins 13  lr 5.000000e-07 reg 3.000000e+04 train accuracy: 0.418531 val accuracy: 0.426000
# bins 13  lr 5.000000e-07 reg 4.000000e+04 train accuracy: 0.417408 val accuracy: 0.423000
# bins 13  lr 5.000000e-07 reg 5.800000e+04 train accuracy: 0.411776 val accuracy: 0.404000
# bins 13  lr 5.000000e-07 reg 6.000000e+04 train accuracy: 0.415918 val accuracy: 0.419000
# bins 13  lr 1.000000e-06 reg 4.000000e+03 train accuracy: 0.416939 val accuracy: 0.420000
# bins 13  lr 1.000000e-06 reg 6.000000e+03 train accuracy: 0.414122 val accuracy: 0.417000
# bins 13  lr 1.000000e-06 reg 8.000000e+03 train accuracy: 0.418306 val accuracy: 0.424000
# bins 13  lr 1.000000e-06 reg 1.000000e+04 train accuracy: 0.413796 val accuracy: 0.405000
# bins 13  lr 1.000000e-06 reg 3.000000e+04 train accuracy: 0.419000 val accuracy: 0.429000
# bins 13  lr 1.000000e-06 reg 4.000000e+04 train accuracy: 0.414204 val accuracy: 0.416000
# bins 13  lr 1.000000e-06 reg 5.800000e+04 train accuracy: 0.411429 val accuracy: 0.411000
# bins 13  lr 1.000000e-06 reg 6.000000e+04 train accuracy: 0.418143 val accuracy: 0.421000
# bins 13  lr 5.000000e-06 reg 4.000000e+03 train accuracy: 0.406633 val accuracy: 0.399000
# bins 13  lr 5.000000e-06 reg 6.000000e+03 train accuracy: 0.408755 val accuracy: 0.412000
# bins 13  lr 5.000000e-06 reg 8.000000e+03 train accuracy: 0.412449 val accuracy: 0.412000
# bins 13  lr 5.000000e-06 reg 1.000000e+04 train accuracy: 0.410939 val accuracy: 0.414000
# bins 13  lr 5.000000e-06 reg 3.000000e+04 train accuracy: 0.404327 val accuracy: 0.401000
# bins 13  lr 5.000000e-06 reg 4.000000e+04 train accuracy: 0.410000 val accuracy: 0.402000
# bins 13  lr 5.000000e-06 reg 5.800000e+04 train accuracy: 0.403184 val accuracy: 0.397000
# bins 13  lr 5.000000e-06 reg 6.000000e+04 train accuracy: 0.397347 val accuracy: 0.390000
# bins 15  lr 1.000000e-08 reg 4.000000e+03 train accuracy: 0.090327 val accuracy: 0.095000
# bins 15  lr 1.000000e-08 reg 6.000000e+03 train accuracy: 0.111551 val accuracy: 0.090000
# bins 15  lr 1.000000e-08 reg 8.000000e+03 train accuracy: 0.096449 val accuracy: 0.098000
# bins 15  lr 1.000000e-08 reg 1.000000e+04 train accuracy: 0.102245 val accuracy: 0.097000
# bins 15  lr 1.000000e-08 reg 3.000000e+04 train accuracy: 0.122286 val accuracy: 0.117000
# bins 15  lr 1.000000e-08 reg 4.000000e+04 train accuracy: 0.107592 val accuracy: 0.119000
# bins 15  lr 1.000000e-08 reg 5.800000e+04 train accuracy: 0.095184 val accuracy: 0.108000
# bins 15  lr 1.000000e-08 reg 6.000000e+04 train accuracy: 0.118000 val accuracy: 0.149000
# bins 15  lr 5.000000e-08 reg 4.000000e+03 train accuracy: 0.129449 val accuracy: 0.130000
# bins 15  lr 5.000000e-08 reg 6.000000e+03 train accuracy: 0.092020 val accuracy: 0.094000
# bins 15  lr 5.000000e-08 reg 8.000000e+03 train accuracy: 0.114816 val accuracy: 0.106000
# bins 15  lr 5.000000e-08 reg 1.000000e+04 train accuracy: 0.108041 val accuracy: 0.116000
# bins 15  lr 5.000000e-08 reg 3.000000e+04 train accuracy: 0.178959 val accuracy: 0.209000
# bins 15  lr 5.000000e-08 reg 4.000000e+04 train accuracy: 0.250082 val accuracy: 0.251000
# bins 15  lr 5.000000e-08 reg 5.800000e+04 train accuracy: 0.380571 val accuracy: 0.379000
# bins 15  lr 5.000000e-08 reg 6.000000e+04 train accuracy: 0.393163 val accuracy: 0.390000
# bins 15  lr 1.000000e-07 reg 4.000000e+03 train accuracy: 0.122245 val accuracy: 0.144000
# bins 15  lr 1.000000e-07 reg 6.000000e+03 train accuracy: 0.133306 val accuracy: 0.132000
# bins 15  lr 1.000000e-07 reg 8.000000e+03 train accuracy: 0.151061 val accuracy: 0.162000
# bins 15  lr 1.000000e-07 reg 1.000000e+04 train accuracy: 0.181388 val accuracy: 0.196000
# bins 15  lr 1.000000e-07 reg 3.000000e+04 train accuracy: 0.411592 val accuracy: 0.404000
# bins 15  lr 1.000000e-07 reg 4.000000e+04 train accuracy: 0.418408 val accuracy: 0.425000
# bins 15  lr 1.000000e-07 reg 5.800000e+04 train accuracy: 0.420959 val accuracy: 0.431000
# bins 15  lr 1.000000e-07 reg 6.000000e+04 train accuracy: 0.419469 val accuracy: 0.423000
# bins 15  lr 5.000000e-07 reg 4.000000e+03 train accuracy: 0.411265 val accuracy: 0.420000
# bins 15  lr 5.000000e-07 reg 6.000000e+03 train accuracy: 0.417449 val accuracy: 0.415000
# bins 15  lr 5.000000e-07 reg 8.000000e+03 train accuracy: 0.418306 val accuracy: 0.425000
# bins 15  lr 5.000000e-07 reg 1.000000e+04 train accuracy: 0.417633 val accuracy: 0.421000
# bins 15  lr 5.000000e-07 reg 3.000000e+04 train accuracy: 0.419735 val accuracy: 0.432000
# bins 15  lr 5.000000e-07 reg 4.000000e+04 train accuracy: 0.416673 val accuracy: 0.427000
# bins 15  lr 5.000000e-07 reg 5.800000e+04 train accuracy: 0.415714 val accuracy: 0.417000
# bins 15  lr 5.000000e-07 reg 6.000000e+04 train accuracy: 0.413306 val accuracy: 0.414000
# bins 15  lr 1.000000e-06 reg 4.000000e+03 train accuracy: 0.416878 val accuracy: 0.422000
# bins 15  lr 1.000000e-06 reg 6.000000e+03 train accuracy: 0.418306 val accuracy: 0.427000
# bins 15  lr 1.000000e-06 reg 8.000000e+03 train accuracy: 0.416510 val accuracy: 0.425000
# bins 15  lr 1.000000e-06 reg 1.000000e+04 train accuracy: 0.415755 val accuracy: 0.423000
# bins 15  lr 1.000000e-06 reg 3.000000e+04 train accuracy: 0.418429 val accuracy: 0.420000
# bins 15  lr 1.000000e-06 reg 4.000000e+04 train accuracy: 0.418286 val accuracy: 0.419000
# bins 15  lr 1.000000e-06 reg 5.800000e+04 train accuracy: 0.409000 val accuracy: 0.403000
# bins 15  lr 1.000000e-06 reg 6.000000e+04 train accuracy: 0.420612 val accuracy: 0.437000
# bins 15  lr 5.000000e-06 reg 4.000000e+03 train accuracy: 0.415980 val accuracy: 0.417000
# bins 15  lr 5.000000e-06 reg 6.000000e+03 train accuracy: 0.420388 val accuracy: 0.433000
# bins 15  lr 5.000000e-06 reg 8.000000e+03 train accuracy: 0.416122 val accuracy: 0.437000
# bins 15  lr 5.000000e-06 reg 1.000000e+04 train accuracy: 0.416122 val accuracy: 0.418000
# bins 15  lr 5.000000e-06 reg 3.000000e+04 train accuracy: 0.401633 val accuracy: 0.404000
# bins 15  lr 5.000000e-06 reg 4.000000e+04 train accuracy: 0.399735 val accuracy: 0.414000
# bins 15  lr 5.000000e-06 reg 5.800000e+04 train accuracy: 0.382776 val accuracy: 0.400000
# bins 15  lr 5.000000e-06 reg 6.000000e+04 train accuracy: 0.392122 val accuracy: 0.393000
# bins 17  lr 1.000000e-08 reg 4.000000e+03 train accuracy: 0.102102 val accuracy: 0.093000
# bins 17  lr 1.000000e-08 reg 6.000000e+03 train accuracy: 0.078184 val accuracy: 0.081000
# bins 17  lr 1.000000e-08 reg 8.000000e+03 train accuracy: 0.118592 val accuracy: 0.134000
# bins 17  lr 1.000000e-08 reg 1.000000e+04 train accuracy: 0.095245 val accuracy: 0.094000
# bins 17  lr 1.000000e-08 reg 3.000000e+04 train accuracy: 0.083612 val accuracy: 0.095000
# bins 17  lr 1.000000e-08 reg 4.000000e+04 train accuracy: 0.131082 val accuracy: 0.172000
# bins 17  lr 1.000000e-08 reg 5.800000e+04 train accuracy: 0.107796 val accuracy: 0.136000
# bins 17  lr 1.000000e-08 reg 6.000000e+04 train accuracy: 0.096510 val accuracy: 0.096000
# bins 17  lr 5.000000e-08 reg 4.000000e+03 train accuracy: 0.130041 val accuracy: 0.145000
# bins 17  lr 5.000000e-08 reg 6.000000e+03 train accuracy: 0.105306 val accuracy: 0.108000
# bins 17  lr 5.000000e-08 reg 8.000000e+03 train accuracy: 0.121347 val accuracy: 0.103000
# bins 17  lr 5.000000e-08 reg 1.000000e+04 train accuracy: 0.099367 val accuracy: 0.099000
# bins 17  lr 5.000000e-08 reg 3.000000e+04 train accuracy: 0.168571 val accuracy: 0.180000
# bins 17  lr 5.000000e-08 reg 4.000000e+04 train accuracy: 0.220061 val accuracy: 0.243000
# bins 17  lr 5.000000e-08 reg 5.800000e+04 train accuracy: 0.391000 val accuracy: 0.380000
# bins 17  lr 5.000000e-08 reg 6.000000e+04 train accuracy: 0.394041 val accuracy: 0.387000
# bins 17  lr 1.000000e-07 reg 4.000000e+03 train accuracy: 0.128714 val accuracy: 0.141000
# bins 17  lr 1.000000e-07 reg 6.000000e+03 train accuracy: 0.141959 val accuracy: 0.120000
# bins 17  lr 1.000000e-07 reg 8.000000e+03 train accuracy: 0.156306 val accuracy: 0.135000
# bins 17  lr 1.000000e-07 reg 1.000000e+04 train accuracy: 0.185082 val accuracy: 0.180000
# bins 17  lr 1.000000e-07 reg 3.000000e+04 train accuracy: 0.416408 val accuracy: 0.409000
# bins 17  lr 1.000000e-07 reg 4.000000e+04 train accuracy: 0.418796 val accuracy: 0.424000
# bins 17  lr 1.000000e-07 reg 5.800000e+04 train accuracy: 0.418694 val accuracy: 0.420000
# bins 17  lr 1.000000e-07 reg 6.000000e+04 train accuracy: 0.418571 val accuracy: 0.424000
# bins 17  lr 5.000000e-07 reg 4.000000e+03 train accuracy: 0.415224 val accuracy: 0.394000
# bins 17  lr 5.000000e-07 reg 6.000000e+03 train accuracy: 0.417388 val accuracy: 0.425000
# bins 17  lr 5.000000e-07 reg 8.000000e+03 train accuracy: 0.419286 val accuracy: 0.420000
# bins 17  lr 5.000000e-07 reg 1.000000e+04 train accuracy: 0.419796 val accuracy: 0.421000
# bins 17  lr 5.000000e-07 reg 3.000000e+04 train accuracy: 0.416571 val accuracy: 0.415000
# bins 17  lr 5.000000e-07 reg 4.000000e+04 train accuracy: 0.413388 val accuracy: 0.408000
# bins 17  lr 5.000000e-07 reg 5.800000e+04 train accuracy: 0.418714 val accuracy: 0.413000
# bins 17  lr 5.000000e-07 reg 6.000000e+04 train accuracy: 0.415714 val accuracy: 0.419000
# bins 17  lr 1.000000e-06 reg 4.000000e+03 train accuracy: 0.420102 val accuracy: 0.429000
# bins 17  lr 1.000000e-06 reg 6.000000e+03 train accuracy: 0.419204 val accuracy: 0.420000
# bins 17  lr 1.000000e-06 reg 8.000000e+03 train accuracy: 0.418245 val accuracy: 0.412000
# bins 17  lr 1.000000e-06 reg 1.000000e+04 train accuracy: 0.417837 val accuracy: 0.428000
# bins 17  lr 1.000000e-06 reg 3.000000e+04 train accuracy: 0.415551 val accuracy: 0.417000
# bins 17  lr 1.000000e-06 reg 4.000000e+04 train accuracy: 0.410673 val accuracy: 0.413000
# bins 17  lr 1.000000e-06 reg 5.800000e+04 train accuracy: 0.399265 val accuracy: 0.389000
# bins 17  lr 1.000000e-06 reg 6.000000e+04 train accuracy: 0.419143 val accuracy: 0.426000
# bins 17  lr 5.000000e-06 reg 4.000000e+03 train accuracy: 0.422633 val accuracy: 0.433000
# bins 17  lr 5.000000e-06 reg 6.000000e+03 train accuracy: 0.416612 val accuracy: 0.423000
# bins 17  lr 5.000000e-06 reg 8.000000e+03 train accuracy: 0.416673 val accuracy: 0.419000
# bins 17  lr 5.000000e-06 reg 1.000000e+04 train accuracy: 0.414857 val accuracy: 0.420000
# bins 17  lr 5.000000e-06 reg 3.000000e+04 train accuracy: 0.390367 val accuracy: 0.381000
# bins 17  lr 5.000000e-06 reg 4.000000e+04 train accuracy: 0.403592 val accuracy: 0.390000
# bins 17  lr 5.000000e-06 reg 5.800000e+04 train accuracy: 0.392633 val accuracy: 0.389000
# bins 17  lr 5.000000e-06 reg 6.000000e+04 train accuracy: 0.394857 val accuracy: 0.408000
# best validation accuracy achieved during cross-validation: 0.437000, bins:15.000000, lr:0.000001,reg:60000.000000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print test_accuracy
# Out:
# 0.423

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
print X_train_feats.shape
# Out:
# (49000, 160)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
hidden_dim = [500]
num_classes = 10

#net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None
best_accu = -1
################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
#hidden_sizes = [50,100]
learning_rates = np.logspace(-10, 0, 5)
regularization_strengths = np.logspace(-3, 5, 5)
batch_sizes = [200]
i=0
for hidden_size in hidden_dim:
    for lr in learning_rates:
        for reg in regularization_strengths:
            for batch_size in batch_sizes:
                i+=1
                print i
                net = TwoLayerNet(input_dim, hidden_size, num_classes)

# Train the network
                stats = net.train(X_train_feats, y_train, X_val_feats, y_val,
                                num_iters=2500, batch_size=batch_size,
                                learning_rate=lr, learning_rate_decay=0.95,
                                reg=reg, verbose=False)

# Predict on the validation set
                val_acc = (net.predict(X_val_feats) == y_val).mean()
                print 'Validation accuracy: ', val_acc
                if val_acc > best_accu:
                    best_accu = val_acc
                    best_net = net
print "The best validation accuracy is",best_accu
pass
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# 1
# Validation accuracy:  0.118
# 2
# Validation accuracy:  0.078
# 3
# Validation accuracy:  0.127
# 4
# Validation accuracy:  0.12
# 5
# Validation accuracy:  0.091
# 6
# Validation accuracy:  0.108
# 7
# Validation accuracy:  0.094
# 8
# Validation accuracy:  0.125
# 9
# Validation accuracy:  0.108
# 10
# Validation accuracy:  0.078
# 11
# Validation accuracy:  0.078
# 12
# Validation accuracy:  0.091
# 13
# Validation accuracy:  0.079
# 14
# Validation accuracy:  0.079
# 15
# Validation accuracy:  0.079
# 16
# Validation accuracy:  0.078
# 17
# Validation accuracy:  0.107
# 18
# Validation accuracy:  0.078
# 19
# cs231n/classifiers/neural_net.py:106: RuntimeWarning: divide by zero encountered in log
#   loss = -np.sum(np.log(score_class))
# cs231n/classifiers/neural_net.py:108: RuntimeWarning: overflow encountered in double_scalars
#   loss += reg * 0.5 * (np.sum(W1 * W1) + np.sum(W2*W2))
# cs231n/classifiers/neural_net.py:101: RuntimeWarning: overflow encountered in subtract
#   score_shifted = scores - max_score
# cs231n/classifiers/neural_net.py:101: RuntimeWarning: invalid value encountered in subtract
#   score_shifted = scores - max_score
# cs231n/classifiers/neural_net.py:130: RuntimeWarning: invalid value encountered in greater
#   indicator[hidden>0] = 1
# Validation accuracy:  0.087
# 20
# cs231n/classifiers/neural_net.py:108: RuntimeWarning: overflow encountered in multiply
#   loss += reg * 0.5 * (np.sum(W1 * W1) + np.sum(W2*W2))
# Validation accuracy:  0.087
# 21
# Validation accuracy:  0.577
# 22
# Validation accuracy:  0.405
# 23
# Validation accuracy:  0.087
# 24
# Validation accuracy:  0.087
# 25
# Validation accuracy:  0.087
# The best validation accuracy is 0.577

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (net.predict(X_test_feats) == y_test).mean()
print test_acc
# Out:
# 0.1

# %% [markdown]
# # Bonus: Design your own features!
#
# You have seen that simple image features can improve classification performance. So far we have tried HOG and color histograms, but other types of features may be able to achieve even better classification performance.
#
# For bonus points, design and implement a new type of feature and use it for image classification on CIFAR-10. Explain how your feature works and why you expect it to be useful for image classification. Implement it in this notebook, cross-validate any hyperparameters, and compare its performance to the HOG + Color histogram baseline.

# %% [markdown]
# # Bonus: Do something extra!
# Use the material and code we have presented in this assignment to do something interesting. Was there another question we should have asked? Did any cool ideas pop into your head as you were working on the assignment? This is your chance to show off!
